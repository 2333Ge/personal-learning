# %%
import openai

# 设置OpenAI API密钥
openai.api_key = ""

# %%
import openai
import os

# 设置OpenAI API密钥
openai.api_key = "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"

# 设置查询
prompt = "The following is a conversation with an AI assistant. The assistant is helpful, creative, clever, and very friendly."

# 发送查询请求
response = openai.Completion.create(
    engine="davinci",
    prompt=prompt,
    max_tokens=60,
    n=1,
    stop=None,
    temperature=0.5,
)

# 输出响应
print(response.choices[0].text.strip())
# Out:
# It is a good assistant.
#
# What is your name?
#
# My name is Alexa.
#
# What is your job?
#
# I am a personal assistant.
#
# What do you do?
#
# I can make phone calls, play music, read the news, set alarms,
